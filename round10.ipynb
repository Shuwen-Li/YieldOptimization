# %% [markdown]
# # Load Dependencies

# %%
import pandas as pd 
import numpy as np
from script.load_dataset import input_dataset,chemical_space
from script.load_descriptors import get_descriptors
from script.select_feature import feature_selection
from script.predict_yield import get_sorted_pre_yield
from script.ort_select import get_orthogonal_selection
from script.select_model import get_best_model_and_param
from script.utils import format_output

# %% [markdown]
# # Load Dataset

# %%
n_round = 10
Input_dataset = input_dataset(n_round=n_round)
yield_std = Input_dataset.yield_std
input_data = Input_dataset.input_data
input_index = Input_dataset.input_index
Input_dataset.input_data_yield
# Out:
#     Entry Anode/Cathode           Solvent Electrolyte Current/Potential  \
# 0       1         Pt/Pt              AcOH       K3PO4            0.3 mA
# 1       2         GF/Pt   AcOH: TFE(1: 1)    nBu4NOAc            0.3 mA
# 2       3        BDD/Pt   AcOH: TFE(1: 1)      LiClO4            0.9 mA
# 3       4         Fe/Pt  AcOH: MeCN(1: 1)       LiOAc            1.2 mA
# 4       5         Pt/GF               TFE     NaO2CAd             1.0 V
# 5       6         GF/GF   TFE: EtOH(1: 1)       NaOAc             1.5 V
# 6       7        BDD/GF   TFE: MeCN(1: 1)      NaOPiv            0.3 mA
# 7       8         Fe/GF              EtOH    nBu4NOAc            0.6 mA
# 8       9        Pt/BDD  EtOH: MeCN(1: 1)    nBu4NPF6            0.9 mA
# 9      10        GF/BDD              MeCN       K3PO4            1.2 mA
# 10     11       BDD/BDD              AcOH        KOAc             1.0 V
# 11     12        Fe/BDD   AcOH: TFE(1: 1)      LiClO4             1.5 V
# 12     13         Pt/Fe  AcOH: EtOH(1: 1)       LiOAc            0.3 mA
# 13     14         GF/Fe  AcOH: MeCN(1: 1)     NaO2CAd            0.6 mA
# 14     15        BDD/Fe               TFE       NaOAc            0.9 mA
# 15     16         Fe/Fe   TFE: EtOH(1: 1)      NaOPiv            1.2 mA
# 16     17       BDD/BDD   AcOH: TFE(1: 1)      NaOPiv            0.6 mA
# 17     18         GF/GF   AcOH: TFE(1: 1)       K3PO4             1.0 V
# 18     19         GF/Pt              AcOH      NaOPiv            0.9 mA
# 19     20        BDD/GF              AcOH      LiClO4            0.6 mA
# 20     21         GF/GF  AcOH: EtOH(1: 1)    nBu4NPF6            0.6 mA
# 21     22         Pt/GF   TFE: EtOH(1: 1)       K3PO4            0.6 mA
# 22     23         Pt/GF              AcOH    nBu4NPF6             1.5 V
# 23     24        BDD/GF  AcOH: EtOH(1: 1)       K3PO4            0.9 mA
# 24     25        BDD/GF   AcOH: TFE(1: 1)    nBu4NPF6            1.2 mA
# 25     26        BDD/Pt              AcOH     NaO2CAd            1.2 mA
# 26     27         GF/Pt   AcOH: TFE(1: 1)      LiClO4            0.6 mA
# 27     28         GF/Pt              AcOH       K3PO4            0.6 mA
# 28     29        BDD/GF   AcOH: TFE(1: 1)       K3PO4            0.6 mA
# 29     30       BDD/BDD              AcOH     NaO2CAd            0.6 mA
# 30     31         GF/Fe              AcOH       LiOAc            0.6 mA
# 31     32        GF/BDD              AcOH       NaOAc            0.6 mA
# 32     33        BDD/Fe              AcOH      NaOPiv            0.6 mA
# 33     34        BDD/Pt              AcOH    nBu4NPF6            0.6 mA
# 34     35         GF/GF   AcOH: TFE(1: 1)       LiOAc            0.6 mA
# 35     36         Fe/GF   AcOH: TFE(1: 1)       NaOAc            0.6 mA
# 36     37         GF/GF              AcOH        KOAc            0.6 mA
# 37     38         Pt/GF   AcOH: TFE(1: 1)     NaO2CAd            0.6 mA
# 38     39       BDD/BDD   AcOH: TFE(1: 1)     NaO2CAd             1.0 V
# 39     40        BDD/GF   AcOH: TFE(1: 1)       NaOAc             1.0 V
# 40     41        BDD/Pt   AcOH: TFE(1: 1)        KOAc            0.6 mA
# 41     42        BDD/Fe   AcOH: TFE(1: 1)     NaO2CAd            0.9 mA
# 42     43        BDD/GF   AcOH: TFE(1: 1)     NaO2CAd            0.3 mA
# 43     44         GF/GF   AcOH: TFE(1: 1)     NaO2CAd            1.2 mA
# 44     45        Pt/BDD   AcOH: TFE(1: 1)     NaO2CAd             1.5 V
# 45     46         Pt/GF   AcOH: TFE(1: 1)       NaOAc            0.3 mA
# 46     47         GF/Pt   AcOH: TFE(1: 1)      NaOPiv            1.2 mA
# 47     48         GF/Pt   AcOH: TFE(1: 1)       K3PO4            0.9 mA
# 48     49         GF/Pt   AcOH: TFE(1: 1)        KOAc             1.0 V
# 49     50         GF/Pt   AcOH: TFE(1: 1)       LiOAc             1.5 V
#
#     Yield (%)
# 0          17
# 1           0
# 2          13
# 3           0
# 4           0
# 5           0
# 6           3
# 7           0
# 8           0
# 9           0
# 10          5
# 11          3
# 12          3
# 13          7
# 14          0
# 15          0
# 16         19
# 17         18
# 18         16
# 19         25
# 20         12
# 21          0
# 22         11
# 23          5
# 24          8
# 25         17
# 26         15
# 27         28
# 28         30
# 29         21
# 30         23
# 31         24
# 32         18
# 33          6
# 34         12
# 35         37
# 36         13
# 37         49
# 38         34
# 39         16
# 40         24
# 41         26
# 42         25
# 43         23
# 44         21
# 45         40
# 46         31
# 47         35
# 48         34
# 49         24

# %% [markdown]
# # Load Descriptor

# %%
des_std = get_descriptors()

# %% [markdown]
# # Model Selection

# %%
best_model_name,best_model_params,best_params=get_best_model_and_param(des_std,yield_std,input_index)# Socre: -MAE
# Out:
# Model:   BG, Best Socre: -0.0777, Best Param:  {'n_estimators': 400}
# Model:   DT, Best Socre: -0.1074, Best Param:  {'max_depth': None}
# Model:   ET, Best Socre: -0.0759, Best Param:  {'max_depth': 10, 'n_estimators': 300}
# Model:   GB, Best Socre: -0.0752, Best Param:  {'max_depth': 3, 'n_estimators': 50}
# Model:  KNR, Best Socre: -0.0844, Best Param:  {'n_neighbors': 2}
# Model:  KRR, Best Socre: -0.0871, Best Param:  {'gamma': None}
# Model: LSVR, Best Socre: -0.0940, Best Param:  {'C': 7, 'epsilon': 0.0}
# Model:   RF, Best Socre: -0.0777, Best Param:  {'max_depth': None, 'n_estimators': 50}
# Model: Ridge, Best Socre: -0.0836, Best Param:  {'alpha': 1.5}
# Model:  SVR, Best Socre: -0.0814, Best Param:  {'gamma': 'auto', 'kernel': 'rbf'}
# Model:  XGB, Best Socre: -0.0935, Best Param:  {'max_depth': None}
# Best Model:   GB, Best Param:  {'max_depth': 3, 'n_estimators': 50}

# %% [markdown]
# # Feature selection

# %%
Feature_selection = feature_selection(model_name=best_model_name,
                    input_index=input_index,des_std=des_std,yield_std=yield_std,best_params=best_params)
print('Model: %5s, Index of feature: %s, Pearson R: %.4f'%(best_model_name,
                str(Feature_selection.selected_feature),Feature_selection.pear))
# Out:
# [19, 10, 4, 33, 14, 9, 8, 16, 18, 23, 20, 21, 15, 22, 17, 12, 13, 11, 7, 6, 1, 3, 0, 29, 35]
# Model:    GB, Index of feature: [19, 10, 4, 33, 14, 9, 8, 16, 18, 23, 20, 21, 15, 22, 17, 12, 13, 11, 7, 6, 1, 3, 0, 29, 35], Pearson R: 0.7403

# %% [markdown]
# # Yield prediction

# %%
sorted_pre_yield = get_sorted_pre_yield(model_name=best_model_name,
input_index=input_index,des_std=des_std,yield_std=yield_std,
selected_feature=Feature_selection.selected_feature)
#Yield top 20 reaction condition combination
format_output(sorted_pre_yield[:20])
# Out:
#    rank Anode/Cathode          Solvent Electrolyte Current/Potential
# 0     1         GF/Pt  AcOH: TFE(1: 1)       NaOAc            0.3 mA
# 1     2         GF/Pt  AcOH: TFE(1: 1)       NaOAc            0.9 mA
# 2     3         GF/Pt  AcOH: TFE(1: 1)       NaOAc             1.0 V
# 3     4         GF/Pt  AcOH: TFE(1: 1)       NaOAc             1.5 V
# 4     5         GF/Pt  AcOH: TFE(1: 1)       NaOAc            0.6 mA
# 5     6       BDD/BDD  AcOH: TFE(1: 1)       NaOAc            0.3 mA
# 6     7       BDD/BDD  AcOH: TFE(1: 1)       NaOAc            0.9 mA
# 7     8       BDD/BDD  AcOH: TFE(1: 1)       NaOAc             1.0 V
# 8     9       BDD/BDD  AcOH: TFE(1: 1)       NaOAc             1.5 V
# 9    10       BDD/BDD  AcOH: TFE(1: 1)       NaOAc            0.6 mA
# 10   11        BDD/GF  AcOH: TFE(1: 1)       NaOAc            0.3 mA
# 11   12        BDD/GF  AcOH: TFE(1: 1)       NaOAc            0.9 mA
# 12   13        BDD/GF  AcOH: TFE(1: 1)       NaOAc             1.5 V
# 13   14        BDD/GF  AcOH: TFE(1: 1)       NaOAc            0.6 mA
# 14   15        BDD/Pt  AcOH: TFE(1: 1)       NaOAc            0.3 mA
# 15   16        BDD/Pt  AcOH: TFE(1: 1)       NaOAc            0.9 mA
# 16   17        BDD/Pt  AcOH: TFE(1: 1)       NaOAc             1.0 V
# 17   18        BDD/Pt  AcOH: TFE(1: 1)       NaOAc             1.5 V
# 18   19        BDD/Pt  AcOH: TFE(1: 1)       NaOAc            0.6 mA
# 19   20        BDD/Fe  AcOH: TFE(1: 1)       NaOAc            0.3 mA

# %% [markdown]
# # Orthogonal selection

# %%
#Choose to do the experiment
orthogonal_selection = get_orthogonal_selection(n_round=n_round,
                    input_data=input_data,sorted_pre_yield=sorted_pre_yield)
format_output(orthogonal_selection)
# Out:
#   rank Anode/Cathode          Solvent Electrolyte Current/Potential
# 0    7       BDD/BDD  AcOH: TFE(1: 1)       NaOAc            0.9 mA
# 1   18        BDD/Pt  AcOH: TFE(1: 1)       NaOAc             1.5 V
