# %% [markdown]
# # Load Dependencies

# %%
from script.utils import *

# %% [markdown]
# # Data_CC

# %%
rundata_dir = './Data/rundata_cc/'
plt.figure(figsize=(18,4))
plt.subplot(141)
results_all_cycle=np.array(pd.read_csv('./doyle_results/1.csv'))[:,1:]
all_max100,num_80,num_85,num_90,yield_80,yield_85,yield_90=get_all_max100_2(results_all_cycle)
print(num_80,num_85,num_90)
recorded_max_mean1=plot_figure4(all_max100,num_80,num_90,yield_80,yield_90,c1='lightblue',c2='blue',title='Bayesian')

plt.subplot(142)
results_all_cycle=np.load(rundata_dir+'results.npy')

all_max100,num_80,num_85,num_90,yield_80,yield_85,yield_90=get_all_max100_2(results_all_cycle)
print(num_80,num_85,num_90)

recorded_max_mean3=plot_figure4(all_max100,num_80,num_90,yield_80,yield_90,c1='lightcoral',c2='red',title='Our Work')

plt.subplot(143)
plt_figure3(recorded_max_mean1,recorded_max_mean3)
# Out:
# 5 6 10
# 3 5 8

# %%
recorded_max_mean1[4],recorded_max_mean1[9],recorded_max_mean3[4],recorded_max_mean3[9],
# Out:
# (77.78840000000002, 88.5994, 83.28, 91.06819999999999)

# %% [markdown]
# # Data_CN

# %%
rundata_dir = './Data/rundata_cn/'
tem_batch_size=5
ten_cc1=3
ten_cc2=1
tem_cc1num=100
tem_cc2num=50
model='rf'

plt.figure(figsize=(18,4))
plt.subplot(141)
results_all_cycle=np.array(pd.read_csv('./doyle_results/2.csv'))[:,1:]
all_max100,num_80,num_85,num_90,yield_80,yield_85,yield_90=get_all_max100_2(results_all_cycle)
print(num_80,num_85,num_90)
recorded_max_mean1=plot_figure4(all_max100,num_80,num_90,yield_80,yield_90,c1='lightblue',c2='blue',title='Bayesian')

plt.subplot(142)
results_all_cycle=np.load(rundata_dir+'results.npy')
all_max100,num_80,num_85,num_90,yield_80,yield_85,yield_90=get_all_max100_2(results_all_cycle)
print(num_80,num_85,num_90)
recorded_max_mean3=plot_figure4(all_max100,num_80,num_90,yield_80,yield_90,c1='lightcoral',c2='red',title='Our Work')

plt.subplot(143)
plt_figure3(recorded_max_mean1,recorded_max_mean3)
# Out:
# 10 13 17
# 6 10 18

# %%
recorded_max_mean1[4],recorded_max_mean1[9],recorded_max_mean3[4],recorded_max_mean3[9],
# Out:
# (66.60194451719998, 79.4133041288, 74.29647571999998, 84.66065954)
